# %%
import librosa

# %%
data, sr = librosa.load('result3.wav', sr=16000) # 时域相加 (100×est_noist + mixed) / abs(max(100×est_noist + mixed))

# %%
sr
# Out:
# 16000

# %%
data
# Out:
# array([-0.02215576, -0.0135498 , -0.01077271, ..., -0.00979614,
#        -0.01040649, -0.01184082], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data)

# %%
noise, sr = librosa.load('result2.wav', sr=16000)
ipd.Audio(noise, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(noise) # est_noise

# %%
spec_result, sr = librosa.load('result1.wav', sr=16000)

# %%
plt.plot(spec_result) # spectrogram result : tensornormalize (est_noise_mag + mixed_mag)

# %%
mixed, sr = librosa.load('mixed.wav', sr=16000)

# %%
plt.plot(mixed+100*noise)

# %%
import IPython.display as ipd
ipd.Audio(mixed+100*noise, rate=16000) # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
